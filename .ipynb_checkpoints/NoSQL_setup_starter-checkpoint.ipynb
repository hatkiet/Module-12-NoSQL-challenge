# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database  <== I wonder why there are 2 identical request for this
db.list_collection_names()
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'West Cottage',
#  'AddressLine2': 'South Foreland Lighthouse',
#  'AddressLine3': 'The Front',
#  'AddressLine4': 'St Margarets Bay',
#  'BusinessName': 'Mrs Knotts Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.492467848017,
#  'FHRSID': 429991,
#  'LocalAuthorityBusinessID': 'PI/000055200',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6HP',
#  'RatingDate': '2019-05-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6600501bc31741ecf921791b'),
#  'geocode': {'latitude': '51.14061', 'longitude': '1.371894'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/429991',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
query = {'BusinessName':'Penang Flavours'}
results_1 = establishments.find(query)

# Pretty print the results
for result in results_1:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6600508da9f0cc21ff947adc'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType':'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

# Capture the results to a variable
results_2 = establishments.find_one(query, fields)

# Pretty print the results
pprint(results_2)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6600501bc31741ecf921791b')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one({'BusinessName': 'Penang Flavours'}, {'$set':{'BusinessTypeID': 1}})

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
results_3 = establishments.find_one(query)

pprint(results_3)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6600508da9f0cc21ff947adc'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}

count_dover = establishments.count_documents(query)

print(f"The number of documents have LocalAuthorityName as Dover is: {count_dover}")
# Out:
# The number of documents have LocalAuthorityName as Dover is: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
db.establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}

recount_dover = establishments.count_documents(query)

print(f"The number of documents have LocalAuthorityName as Dover is: {recount_dover}")
# Out:
# The number of documents have LocalAuthorityName as Dover is: 0

# %%
# Check that other documents remain with 'find_one'
db.establishments.find_one()
# Out:
# {'_id': ObjectId('6600501bc31741ecf9217bff'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
db.establishments.update_many({}, [
                                    {'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'}}},
                                    {'$set': {'geocode.latitude': {'$toDouble': '$geocode.latitude'}}}
                                   ]
                              )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
db.establishments.update_many({},[
    {'$set': {'RatingValue': {'$toInt': '$RatingValue'}}}
])

# %%
# Check that the coordinates and rating value are now numbers
query = {}
fields = {'geocode.longitude': 1, 'geocode.latitude': 1, 'RatingValue': 1}

results_4 = db.establishments.find(query, fields)

for result in results_4: 
    pprint(result)
# Out:
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217bff'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c00'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c03'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c04'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c06'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c07'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c08'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c09'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c0a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c0c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c0e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c0f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c10'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c11'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c12'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c13'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c14'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c15'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c16'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c17'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c18'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c19'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c1a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c1b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c1c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c1d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c1e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 2,
#  '_id': ObjectId('6600501bc31741ecf9217c1f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c20'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c21'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c22'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c23'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c24'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c25'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 2,
#  '_id': ObjectId('6600501bc31741ecf9217c26'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c27'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c28'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c29'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c2a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c2b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c2c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c2d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c2e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c2f'),
#  'geocode': {'latitude': 51.080446, 'longitude': 1.186825}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c30'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'RatingValue': 2,
#  '_id': ObjectId('6600501bc31741ecf9217c31'),
#  'geocode': {'latitude': 51.078449, 'longitude': 1.18516}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c32'),
#  'geocode': {'latitude': 51.0805695006979, 'longitude': 1.18794649942731}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c36'),
#  'geocode': {'latitude': 51.087887, 'longitude': 1.194306}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c37'),
#  'geocode': {'latitude': 51.080224, 'longitude': 1.186067}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c38'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c39'),
#  'geocode': {'latitude': 51.095015, 'longitude': 1.202055}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c3a'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c3b'),
#  'geocode': {'latitude': 51.080673, 'longitude': 1.187083}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c3c'),
#  'geocode': {'latitude': 51.077971, 'longitude': 1.183585}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c3d'),
#  'geocode': {'latitude': 51.083232, 'longitude': 1.188902}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c3e'),
#  'geocode': {'latitude': 51.079985650005, 'longitude': 1.18628335007084}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c3f'),
#  'geocode': {'latitude': 51.080838, 'longitude': 1.186309}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c40'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c41'),
#  'geocode': {'latitude': 51.081546, 'longitude': 1.186715}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c43'),
#  'geocode': {'latitude': 51.0803, 'longitude': 1.184916}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c46'),
#  'geocode': {'latitude': 51.081735, 'longitude': 1.187056}}
# {'RatingValue': 2,
#  '_id': ObjectId('6600501bc31741ecf9217c47'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c48'),
#  'geocode': {'latitude': 51.0818061828613, 'longitude': 1.18601894378662}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c4a'),
#  'geocode': {'latitude': 51.0877821, 'longitude': 1.1920251}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c4b'),
#  'geocode': {'latitude': 51.086262, 'longitude': 1.190896}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c4d'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c4e'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c4f'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c50'),
#  'geocode': {'latitude': 51.079301, 'longitude': 1.182962}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c51'),
#  'geocode': {'latitude': 51.0804748535156, 'longitude': 1.18425798416138}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c52'),
#  'geocode': {'latitude': 51.0809478759766, 'longitude': 1.18431901931763}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c53'),
#  'geocode': {'latitude': 51.0793, 'longitude': 1.182962}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c54'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c55'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c56'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c57'),
#  'geocode': {'latitude': 51.0917365039471, 'longitude': 1.19522100055125}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c58'),
#  'geocode': {'latitude': 51.0810258, 'longitude': 1.1835476}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c59'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c5a'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c5b'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c5c'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c5d'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c5e'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c60'),
#  'geocode': {'latitude': 51.097794, 'longitude': 1.201433}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c61'),
#  'geocode': {'latitude': 51.079905, 'longitude': 1.182875}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c62'),
#  'geocode': {'latitude': 51.079532623291, 'longitude': 1.1813759803772}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c63'),
#  'geocode': {'latitude': 51.080804, 'longitude': 1.183893}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c64'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c65'),
#  'geocode': {'latitude': 51.080805, 'longitude': 1.183894}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c66'),
#  'geocode': {'latitude': 51.0798931, 'longitude': 1.1817077}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c67'),
#  'geocode': {'latitude': 51.0802956, 'longitude': 1.1823865}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c68'),
#  'geocode': {'latitude': 51.0803409, 'longitude': 1.1822069}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c69'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c6a'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c6b'),
#  'geocode': {'latitude': 51.079889, 'longitude': 1.181832}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c6c'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c6d'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c6e'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c6f'),
#  'geocode': {'latitude': 51.079799, 'longitude': 1.181482}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c70'),
#  'geocode': {'latitude': 51.0798, 'longitude': 1.181483}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c71'),
#  'geocode': {'latitude': 51.078209, 'longitude': 1.179446}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c72'),
#  'geocode': {'latitude': 51.0802346, 'longitude': 1.1814856}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c73'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c74'),
#  'geocode': {'latitude': 51.0797886, 'longitude': 1.1810166}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c75'),
#  'geocode': {'latitude': 51.0800235, 'longitude': 1.1813097}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c76'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c77'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c78'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c79'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c7a'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c7b'),
#  'geocode': {'latitude': 51.0806732177734, 'longitude': 1.18172800540924}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c7c'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c7d'),
#  'geocode': {'latitude': 51.082322, 'longitude': 1.183327}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c7e'),
#  'geocode': {'latitude': 51.0793698, 'longitude': 1.1802781}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c7f'),
#  'geocode': {'latitude': 51.083976, 'longitude': 1.185011}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c80'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c81'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c82'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c83'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c84'),
#  'geocode': {'latitude': 51.0816612, 'longitude': 1.1826116}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c85'),
#  'geocode': {'latitude': 51.08472, 'longitude': 1.185748}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c86'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c87'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c88'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'RatingValue': 2,
#  '_id': ObjectId('6600501bc31741ecf9217c89'),
#  'geocode': {'latitude': 51.084721, 'longitude': 1.185748}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c8a'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c8b'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c8c'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c8d'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c8e'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c8f'),
#  'geocode': {'latitude': 51.0806941, 'longitude': 1.1817227}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217c90'),
#  'geocode': {'latitude': 51.0818634033203, 'longitude': 1.18279695510864}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c91'),
#  'geocode': {'latitude': 51.0804176330566, 'longitude': 1.18128204345703}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c92'),
#  'geocode': {'latitude': 51.080181, 'longitude': 1.181023}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c93'),
#  'geocode': {'latitude': 51.081494, 'longitude': 1.182356}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c94'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c95'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c96'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c97'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217c98'),
#  'geocode': {'latitude': 51.0785865783691, 'longitude': 1.17911505699158}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c99'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c9a'),
#  'geocode': {'latitude': 51.0802287, 'longitude': 1.1806797}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c9b'),
#  'geocode': {'latitude': 51.078117, 'longitude': 1.1784815}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c9c'),
#  'geocode': {'latitude': 51.078587, 'longitude': 1.179115}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c9d'),
#  'geocode': {'latitude': 51.0780695, 'longitude': 1.1785097}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217c9e'),
#  'geocode': {'latitude': 51.0798709, 'longitude': 1.1803396}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c9f'),
#  'geocode': {'latitude': 51.085454, 'longitude': 1.186241}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501bc31741ecf9217ca0'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217ca1'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217ca2'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217ca3'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217ca4'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217ca5'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217ca6'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217ca7'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217ca8'),
#  'geocode': {'latitude': 51.078131, 'longitude': 1.178027}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217caa'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217cab'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217cac'),
#  'geocode': {'latitude': 51.081526, 'longitude': 1.181201}}
# {'RatingValue': 1,
#  '_id': ObjectId('6600501bc31741ecf9217cad'),
#  'geocode': {'latitude': 51.080217, 'longitude': 1.1799178}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217caf'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb0'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb1'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217cb2'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb3'),
#  'geocode': {'latitude': 51.0783483, 'longitude': 1.177752}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb4'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179925}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb5'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb7'),
#  'geocode': {'latitude': 51.0783433, 'longitude': 1.1776046}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb8'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cb9'),
#  'geocode': {'latitude': 51.079481, 'longitude': 1.178961}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cba'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cbb'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cbc'),
#  'geocode': {'latitude': 51.079161, 'longitude': 1.17884}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501bc31741ecf9217cbd'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cbe'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cbf'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cc1'),
#  'geocode': {'latitude': 51.0806446, 'longitude': 1.1796215}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cc2'),
#  'geocode': {'latitude': 51.087132, 'longitude': 1.186371}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cc3'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cc4'),
#  'geocode': {'latitude': 51.080668, 'longitude': 1.179628}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217cc5'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501bc31741ecf9217cc6'),
#  'geocode': {'latitude': 51.0824157, 'longitude': 1.1817418}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501bc31741ecf9217c
}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d3fb'),
#  'geocode': {'latitude': 51.4880981445313, 'longitude': 0.281677007675171}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d3fc'),
#  'geocode': {'latitude': 51.487302, 'longitude': 0.281385}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d3fd'),
#  'geocode': {'latitude': 51.620081, 'longitude': 0.415894}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d3fe'),
#  'geocode': {'latitude': 51.4556999206543, 'longitude': 0.248845994472504}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d3ff'),
#  'geocode': {'latitude': 51.4880981445313, 'longitude': 0.281677007675171}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d400'),
#  'geocode': {'latitude': 51.9893073, 'longitude': 0.7982926}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d401'),
#  'geocode': {'latitude': 51.487302, 'longitude': 0.281385}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501cc31741ecf921d402'),
#  'geocode': {'latitude': 51.4880981445313, 'longitude': 0.281677007675171}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d403'),
#  'geocode': {'latitude': 51.245715, 'longitude': 0.038887}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d404'),
#  'geocode': {'latitude': 51.245622, 'longitude': 0.038052}}
# {'RatingValue': 3,
#  '_id': ObjectId('6600501cc31741ecf921d405'),
#  'geocode': {'latitude': 51.4884223937988, 'longitude': 0.28158301115036}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d406'),
#  'geocode': {'latitude': 51.4884223937988, 'longitude': 0.28158301115036}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d407'),
#  'geocode': {'latitude': 51.4884223937988, 'longitude': 0.28158301115036}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d408'),
#  'geocode': {'latitude': 51.4884223937988, 'longitude': 0.28158301115036}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501cc31741ecf921d409'),
#  'geocode': {'latitude': 51.623225, 'longitude': 0.418692}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d40a'),
#  'geocode': {'latitude': 51.487302, 'longitude': 0.281385}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d40b'),
#  'geocode': {'latitude': 51.620399, 'longitude': 0.415753}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d40c'),
#  'geocode': {'latitude': 51.4838714599609, 'longitude': 0.277022987604141}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501cc31741ecf921d40d'),
#  'geocode': {'latitude': 51.4856779, 'longitude': 0.2788966}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501cc31741ecf921d40e'),
#  'geocode': {'latitude': 51.620399, 'longitude': 0.415753}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501cc31741ecf921d40f'),
#  'geocode': {'latitude': 51.620399, 'longitude': 0.415753}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501cc31741ecf921d410'),
#  'geocode': {'latitude': 51.487586, 'longitude': 0.28065}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d411'),
#  'geocode': {'latitude': 51.4878311157227, 'longitude': 0.280876994132996}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d412'),
#  'geocode': {'latitude': 51.4859575, 'longitude': 0.2788529}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501cc31741ecf921d413'),
#  'geocode': {'latitude': 51.4859575, 'longitude': 0.2788529}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d414'),
#  'geocode': {'latitude': 51.248277, 'longitude': 0.039946}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d415'),
#  'geocode': {'latitude': 51.623256, 'longitude': 0.418086}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501cc31741ecf921d416'),
#  'geocode': {'latitude': 51.4393263, 'longitude': 0.2312754}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501cc31741ecf921d417'),
#  'geocode': {'latitude': 51.442586, 'longitude': 0.234387}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d418'),
#  'geocode': {'latitude': 51.4884223937988, 'longitude': 0.28158301115036}}
# {'RatingValue': None,
#  '_id': ObjectId('6600501cc31741ecf921d419'),
#  'geocode': {'latitude': 51.813973, 'longitude': 0.614135}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501cc31741ecf921d41a'),
#  'geocode': {'latitude': 52.0085158, 'longitude': 0.816959}}
# {'RatingValue': 4,
#  '_id': ObjectId('6600501cc31741ecf921d41b'),
#  'geocode': {'latitude': 51.620399, 'longitude': 0.415753}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d41c'),
#  'geocode': {'latitude': 51.4858967, 'longitude': 0.2778251}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d41d'),
#  'geocode': {'latitude': 51.870007, 'longitude': 0.671863}}
# {'RatingValue': 2,
#  '_id': ObjectId('6600501cc31741ecf921d41e'),
#  'geocode': {'latitude': 51.3954686, 'longitude': 0.1864034}}
# {'RatingValue': 5,
#  '_id': ObjectId('6600501cc31741ecf921d41f'),
#  'geocode': {'latitude': 51.9709739685059, 'longitude': 0.777417004108429}}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
